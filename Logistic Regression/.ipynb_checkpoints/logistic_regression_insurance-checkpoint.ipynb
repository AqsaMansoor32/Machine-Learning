# %% [markdown]
# <h2 style="color:green" align="center">Predicting if a person would buy life insurnace based on his age using logistic regression</h2>

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("data/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               27 non-null     int64
#  1   bought_insurance  27 non-null     int64
# dtypes: int64(2)
# memory usage: 564.0 bytes

# %%
plt.scatter(df.age,df.bought_insurance,color='red',marker='o')
plt.title("Age VS Insurance")
plt.xlabel("Age")
plt.ylabel("Insurance")
plt.show()

# %%
df.shape
# Out:
# (27, 2)

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
X=df.drop(columns=['bought_insurance'])
y=df['bought_insurance']

# %%
X
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     age
# 0    22
# 16   25
# 4    46
# 24   50
# 13   29
# 26   23
# 15   55
# 11   28
# 22   40
# 17   58
# 6    55
# 1    25
# 10   18
# 12   27
# 18   19
# 20   21
# 5    56
# 8    62
# 21   26
# 14   49
# 3    52

# %%
X_test
# Out:
#     age
# 2    47
# 19   18
# 7    60
# 9    61
# 25   54
# 23   45

# %%
y_train
# Out:
# 0     0
# 16    1
# 4     1
# 24    1
# 13    0
# 26    0
# 15    1
# 11    0
# 22    1
# 17    1
# 6     0
# 1     0
# 10    0
# 12    0
# 18    0
# 20    0
# 5     1
# 8     1
# 21    0
# 14    1
# 3     0
# Name: bought_insurance, dtype: int64

# %%
y_test
# Out:
# 2     1
# 19    0
# 7     1
# 9     1
# 25    1
# 23    1
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([1, 0, 1, 1, 1, 1])

# %%
pd.DataFrame({'y_test':y_test,'y_predict':y_predicted})
# Out:
#     y_test  y_predict
# 2        1          1
# 19       0          0
# 7        1          1
# 9        1          1
# 25       1          1
# 23       1          1

# %%
model.predict_proba(X_test)
# Out:
# array([[0.33806489, 0.66193511],
#        [0.93670281, 0.06329719],
#        [0.10146698, 0.89853302],
#        [0.0913622 , 0.9086378 ],
#        [0.18474534, 0.81525466],
#        [0.39179807, 0.60820193]])

# %%
model.score(X_test,y_test)     #accuracy in classification and R2 in regression
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([1, 0, 1, 1, 1, 1])

# %%
X_test
# Out:
#     age
# 2    47
# 19   18
# 7    60
# 9    61
# 25   54
# 23   45

# %% [markdown]
# **model.coef_ indicates value of m in y=m*x + b equation**

# %%
model.coef_
# Out:
# array([[0.11608465]])

# %% [markdown]
# **model.intercept_ indicates value of b in y=m*x + b equation**

# %%
model.intercept_
# Out:
# array([-4.78404869])

# %% [markdown]
# **Lets defined sigmoid function now and do the math with hand**

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age): 
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z) 
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %% [markdown]
# **0.485 is less than 0.5 which means person with 35 age will *not* buy insurance**

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705

# %% [markdown]
# **0.485 is more than 0.5 which means person with 43 will buy the insurance**

# %%
def predict_probability(age_input):
    """
    Predict probability of class 1 for given age(s)
    age_input : int, float, or list/array of ages
    """
    age_array = np.array(age_input).reshape(-1, 1)  # convert to 2D array
    prob = model.predict_proba(age_array)[:, 1]        # probability of class 1
    return prob

def predict_class(age_input, threshold=0.5):
    """
    Predict class label (0 or 1) for given age(s)
    """
    prob = predict_probability(age_input)
    return (prob > threshold).astype(int)

# %%
print(predict_probability(30))  # e.g., [0.42] → 42% chance
# Out:
# [0.21391111]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import math

def prediction(age):
    # Step 1: calculate a score
    z = 0.042 * age - 1.53
    
    # Step 2: turn score into probability
    prob = 1 / (1 + math.exp(-z))
    
    # Step 3: print probability and decision
    print(f"Age: {age}, Probability: {prob:.2f}")
    if prob > 0.5:
        print("Prediction: YES (1)")
    else:
        print("Prediction: NO (0)")

# %%
prediction(30)
prediction(45)
# Out:
# Age: 30, Probability: 0.43
# Prediction: NO (0)
# Age: 45, Probability: 0.59
# Prediction: YES (1)
